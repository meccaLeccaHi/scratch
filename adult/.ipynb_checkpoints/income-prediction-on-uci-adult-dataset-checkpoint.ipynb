# %% [markdown]
# # Consensus
# [source](https://www.kaggle.com/overload10/income-prediction-on-uci-adult-dataset)

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %% [markdown]
# ### Loading *csv* file in *dataframe*

# %%
df = pd.read_csv("./large_train_sample.csv",1,",")
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship      sex  \
# 0        Never-married        Adm-clerical   Not-in-family     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country    wage
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
df = df.rename(index=str, columns={"native-country": "country", "wage": "salary"})

# %% [markdown]
# ### Convert *salary* to integer

# %%
salary_map={' <=50K':1,' >50K':0}
df['salary']=df['salary'].map(salary_map).astype(int)
    
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship      sex  \
# 0           Never-married        Adm-clerical   Not-in-family     Male
# 1      Married-civ-spouse     Exec-managerial         Husband     Male
# 2                Divorced   Handlers-cleaners   Not-in-family     Male
# 3      Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4      Married-civ-spouse      Prof-specialty            Wife   Female
# 5      Married-civ-spouse     Exec-managerial            Wife   Female
# 6   Married-spouse-absent       Other-service   Not-in-family   Female
# 7      Married-civ-spouse     Exec-managerial         Husband     Male
# 8           Never-married      Prof-specialty   Not-in-family   Female
# 9      Married-civ-spouse     Exec-managerial         Husband     Male
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States       1
# 1             0             0              13   United-States       1
# 2             0             0              40   United-States       1
# 3             0             0              40   United-States       1
# 4             0             0              40            Cuba       1
# 5             0             0              40   United-States       1
# 6             0             0              16         Jamaica       1
# 7             0             0              45   United-States       0
# 8         14084             0              50   United-States       0
# 9          5178             0              40   United-States       0

# %% [markdown]
# ### convert *sex* into *integer*

# %%
df['sex'] = df['sex'].map({' Male':1,' Female':0}).astype(int)
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship  sex  \
# 0           Never-married        Adm-clerical   Not-in-family    1
# 1      Married-civ-spouse     Exec-managerial         Husband    1
# 2                Divorced   Handlers-cleaners   Not-in-family    1
# 3      Married-civ-spouse   Handlers-cleaners         Husband    1
# 4      Married-civ-spouse      Prof-specialty            Wife    0
# 5      Married-civ-spouse     Exec-managerial            Wife    0
# 6   Married-spouse-absent       Other-service   Not-in-family    0
# 7      Married-civ-spouse     Exec-managerial         Husband    1
# 8           Never-married      Prof-specialty   Not-in-family    0
# 9      Married-civ-spouse     Exec-managerial         Husband    1
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States       1
# 1             0             0              13   United-States       1
# 2             0             0              40   United-States       1
# 3             0             0              40   United-States       1
# 4             0             0              40            Cuba       1
# 5             0             0              40   United-States       1
# 6             0             0              16         Jamaica       1
# 7             0             0              45   United-States       0
# 8         14084             0              50   United-States       0
# 9          5178             0              40   United-States       0

# %% [markdown]
# ### Find correlation between columns

# %%
def plot_correlation(df, size=15):
    corr= df.corr()
    fig, ax =plt.subplots(figsize=(size,size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)),corr.columns)
    plt.yticks(range(len(corr.columns)),corr.columns)
    plt.show()

# %%
plot_correlation(df)

# %% [markdown]
# ### Categorise in US and Non-US candidates

# %%
df[['country','salary']].groupby(['country']).mean()
# Out:
#                                salary
# country
#  ?                           0.749571
#  Cambodia                    0.631579
#  Canada                      0.677686
#  China                       0.733333
#  Columbia                    0.966102
#  Cuba                        0.736842
#  Dominican-Republic          0.971429
#  Ecuador                     0.857143
#  El-Salvador                 0.915094
#  England                     0.666667
#  France                      0.586207
#  Germany                     0.678832
#  Greece                      0.724138
#  Guatemala                   0.953125
#  Haiti                       0.909091
#  Holand-Netherlands          1.000000
#  Honduras                    0.923077
#  Hong                        0.700000
#  Hungary                     0.769231
#  India                       0.600000
#  Iran                        0.581395
#  Ireland                     0.791667
#  Italy                       0.657534
#  Jamaica                     0.876543
#  Japan                       0.612903
#  Laos                        0.888889
#  Mexico                      0.948678
#  Nicaragua                   0.941176
#  Outlying-US(Guam-USVI-etc)  1.000000
#  Peru                        0.935484
#  Philippines                 0.691919
#  Poland                      0.800000
#  Portugal                    0.891892
#  Puerto-Rico                 0.894737
#  Scotland                    0.750000
#  South                       0.800000
#  Taiwan                      0.607843
#  Thailand                    0.833333
#  Trinadad&Tobago             0.894737
#  United-States               0.754165
#  Vietnam                     0.925373
#  Yugoslavia                  0.625000

# %% [markdown]
# ### Drop empty value marked as '?'

# %%
print(df.shape)
df['workclass'] = df['workclass'].replace(' ?',np.nan)
df['occupation'] = df['occupation'].replace(' ?',np.nan)

df.dropna(how='any',inplace=True)

print(df.shape)
df.head(10)
# Out:
# (32561, 14)
# (30718, 14)
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship  sex  \
# 0           Never-married        Adm-clerical   Not-in-family    1
# 1      Married-civ-spouse     Exec-managerial         Husband    1
# 2                Divorced   Handlers-cleaners   Not-in-family    1
# 3      Married-civ-spouse   Handlers-cleaners         Husband    1
# 4      Married-civ-spouse      Prof-specialty            Wife    0
# 5      Married-civ-spouse     Exec-managerial            Wife    0
# 6   Married-spouse-absent       Other-service   Not-in-family    0
# 7      Married-civ-spouse     Exec-managerial         Husband    1
# 8           Never-married      Prof-specialty   Not-in-family    0
# 9      Married-civ-spouse     Exec-managerial         Husband    1
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States       1
# 1             0             0              13   United-States       1
# 2             0             0              40   United-States       1
# 3             0             0              40   United-States       1
# 4             0             0              40            Cuba       1
# 5             0             0              40   United-States       1
# 6             0             0              16         Jamaica       1
# 7             0             0              45   United-States       0
# 8         14084             0              50   United-States       0
# 9          5178             0              40   United-States       0

# %%
df.loc[df['country'] != ' United-States', 'country'] = 'Non-US'
df.loc[df['country'] == ' United-States', 'country'] = 'US'
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship  sex  \
# 0           Never-married        Adm-clerical   Not-in-family    1
# 1      Married-civ-spouse     Exec-managerial         Husband    1
# 2                Divorced   Handlers-cleaners   Not-in-family    1
# 3      Married-civ-spouse   Handlers-cleaners         Husband    1
# 4      Married-civ-spouse      Prof-specialty            Wife    0
# 5      Married-civ-spouse     Exec-managerial            Wife    0
# 6   Married-spouse-absent       Other-service   Not-in-family    0
# 7      Married-civ-spouse     Exec-managerial         Husband    1
# 8           Never-married      Prof-specialty   Not-in-family    0
# 9      Married-civ-spouse     Exec-managerial         Husband    1
#
#    capital-gain  capital-loss  hours-per-week country  salary
# 0          2174             0              40      US       1
# 1             0             0              13      US       1
# 2             0             0              40      US       1
# 3             0             0              40      US       1
# 4             0             0              40  Non-US       1
# 5             0             0              40      US       1
# 6             0             0              16  Non-US       1
# 7             0             0              45      US       0
# 8         14084             0              50      US       0
# 9          5178             0              40      US       0

# %% [markdown]
# ### Convert *country* in *integer*

# %%
df['country'] = df['country'].map({'US':1,'Non-US':0}).astype(int)

# %%
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship  sex  \
# 0           Never-married        Adm-clerical   Not-in-family    1
# 1      Married-civ-spouse     Exec-managerial         Husband    1
# 2                Divorced   Handlers-cleaners   Not-in-family    1
# 3      Married-civ-spouse   Handlers-cleaners         Husband    1
# 4      Married-civ-spouse      Prof-specialty            Wife    0
# 5      Married-civ-spouse     Exec-managerial            Wife    0
# 6   Married-spouse-absent       Other-service   Not-in-family    0
# 7      Married-civ-spouse     Exec-managerial         Husband    1
# 8           Never-married      Prof-specialty   Not-in-family    0
# 9      Married-civ-spouse     Exec-managerial         Husband    1
#
#    capital-gain  capital-loss  hours-per-week  country  salary
# 0          2174             0              40        1       1
# 1             0             0              13        1       1
# 2             0             0              40        1       1
# 3             0             0              40        1       1
# 4             0             0              40        0       1
# 5             0             0              40        1       1
# 6             0             0              16        0       1
# 7             0             0              45        1       0
# 8         14084             0              50        1       0
# 9          5178             0              40        1       0

# %% [markdown]
# ### Data visualisation using histogram

# %%
x= df['hours-per-week']
plt.hist(x,bins=None,density=True,normed=None,histtype='bar')
plt.show()

# %%
df[['relationship','salary']].groupby(['relationship']).mean()
# Out:
#                    salary
# relationship
#  Husband         0.544317
#  Not-in-family   0.893452
#  Other-relative  0.960784
#  Own-child       0.985414
#  Unmarried       0.933965
#  Wife            0.508711

# %%
df[['marital-status','salary']].groupby(['marital-status']).mean()
# Out:
#                           salary
# marital-status
#  Divorced               0.892673
#  Married-AF-spouse      0.523810
#  Married-civ-spouse     0.545226
#  Married-spouse-absent  0.915167
#  Never-married          0.951372
#  Separated              0.931178
#  Widowed                0.903571

# %% [markdown]
# ### Categorise marital-status into single and couple

# %%
df['marital-status'] = df['marital-status'].replace([' Divorced',' Married-spouse-absent',' Never-married',' Separated',' Widowed'],'Single')
df['marital-status'] = df['marital-status'].replace([' Married-AF-spouse',' Married-civ-spouse'],'Couple')

df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num marital-status  \
# 0   39          State-gov   77516   Bachelors             13         Single
# 1   50   Self-emp-not-inc   83311   Bachelors             13         Couple
# 2   38            Private  215646     HS-grad              9         Single
# 3   53            Private  234721        11th              7         Couple
# 4   28            Private  338409   Bachelors             13         Couple
# 5   37            Private  284582     Masters             14         Couple
# 6   49            Private  160187         9th              5         Single
# 7   52   Self-emp-not-inc  209642     HS-grad              9         Couple
# 8   31            Private   45781     Masters             14         Single
# 9   42            Private  159449   Bachelors             13         Couple
#
#            occupation    relationship  sex  capital-gain  capital-loss  \
# 0        Adm-clerical   Not-in-family    1          2174             0
# 1     Exec-managerial         Husband    1             0             0
# 2   Handlers-cleaners   Not-in-family    1             0             0
# 3   Handlers-cleaners         Husband    1             0             0
# 4      Prof-specialty            Wife    0             0             0
# 5     Exec-managerial            Wife    0             0             0
# 6       Other-service   Not-in-family    0             0             0
# 7     Exec-managerial         Husband    1             0             0
# 8      Prof-specialty   Not-in-family    0         14084             0
# 9     Exec-managerial         Husband    1          5178             0
#
#    hours-per-week  country  salary
# 0              40        1       1
# 1              13        1       1
# 2              40        1       1
# 3              40        1       1
# 4              40        0       1
# 5              40        1       1
# 6              16        0       1
# 7              45        1       0
# 8              50        1       0
# 9              40        1       0

# %%
df[['marital-status','salary']].groupby(['marital-status']).mean()
# Out:
#                   salary
# marital-status
# Couple          0.545195
# Single          0.931593

# %%
df[['marital-status','relationship','salary']].groupby(['marital-status','relationship']).mean()
# Out:
#                                   salary
# marital-status relationship
# Couple          Husband         0.544317
#                 Not-in-family   0.714286
#                 Other-relative  0.858333
#                 Own-child       0.816092
#                 Wife            0.508711
# Single          Not-in-family   0.893771
#                 Other-relative  0.976190
#                 Own-child       0.988734
#                 Unmarried       0.933965

# %%
df[['marital-status','relationship','salary']].groupby(['relationship','marital-status']).mean()
# Out:
#                                   salary
# relationship    marital-status
#  Husband        Couple          0.544317
#  Not-in-family  Couple          0.714286
#                 Single          0.893771
#  Other-relative Couple          0.858333
#                 Single          0.976190
#  Own-child      Couple          0.816092
#                 Single          0.988734
#  Unmarried      Single          0.933965
#  Wife           Couple          0.508711

# %%
df['marital-status'] = df['marital-status'].map({'Couple':0,'Single':1})
   
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  marital-status  \
# 0   39          State-gov   77516   Bachelors             13               1
# 1   50   Self-emp-not-inc   83311   Bachelors             13               0
# 2   38            Private  215646     HS-grad              9               1
# 3   53            Private  234721        11th              7               0
# 4   28            Private  338409   Bachelors             13               0
# 5   37            Private  284582     Masters             14               0
# 6   49            Private  160187         9th              5               1
# 7   52   Self-emp-not-inc  209642     HS-grad              9               0
# 8   31            Private   45781     Masters             14               1
# 9   42            Private  159449   Bachelors             13               0
#
#            occupation    relationship  sex  capital-gain  capital-loss  \
# 0        Adm-clerical   Not-in-family    1          2174             0
# 1     Exec-managerial         Husband    1             0             0
# 2   Handlers-cleaners   Not-in-family    1             0             0
# 3   Handlers-cleaners         Husband    1             0             0
# 4      Prof-specialty            Wife    0             0             0
# 5     Exec-managerial            Wife    0             0             0
# 6       Other-service   Not-in-family    0             0             0
# 7     Exec-managerial         Husband    1             0             0
# 8      Prof-specialty   Not-in-family    0         14084             0
# 9     Exec-managerial         Husband    1          5178             0
#
#    hours-per-week  country  salary
# 0              40        1       1
# 1              13        1       1
# 2              40        1       1
# 3              40        1       1
# 4              40        0       1
# 5              40        1       1
# 6              16        0       1
# 7              45        1       0
# 8              50        1       0
# 9              40        1       0

# %%
rel_map = {' Unmarried':0,' Wife':1,' Husband':2,' Not-in-family':3,' Own-child':4,' Other-relative':5}

df['relationship'] = df['relationship'].map(rel_map)
    
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  marital-status  \
# 0   39          State-gov   77516   Bachelors             13               1
# 1   50   Self-emp-not-inc   83311   Bachelors             13               0
# 2   38            Private  215646     HS-grad              9               1
# 3   53            Private  234721        11th              7               0
# 4   28            Private  338409   Bachelors             13               0
# 5   37            Private  284582     Masters             14               0
# 6   49            Private  160187         9th              5               1
# 7   52   Self-emp-not-inc  209642     HS-grad              9               0
# 8   31            Private   45781     Masters             14               1
# 9   42            Private  159449   Bachelors             13               0
#
#            occupation  relationship  sex  capital-gain  capital-loss  \
# 0        Adm-clerical             3    1          2174             0
# 1     Exec-managerial             2    1             0             0
# 2   Handlers-cleaners             3    1             0             0
# 3   Handlers-cleaners             2    1             0             0
# 4      Prof-specialty             1    0             0             0
# 5     Exec-managerial             1    0             0             0
# 6       Other-service             3    0             0             0
# 7     Exec-managerial             2    1             0             0
# 8      Prof-specialty             3    0         14084             0
# 9     Exec-managerial             2    1          5178             0
#
#    hours-per-week  country  salary
# 0              40        1       1
# 1              13        1       1
# 2              40        1       1
# 3              40        1       1
# 4              40        0       1
# 5              40        1       1
# 6              16        0       1
# 7              45        1       0
# 8              50        1       0
# 9              40        1       0

# %%
df[['occupation','salary']].groupby(['occupation']).mean()
# Out:
#                       salary
# occupation
#  Adm-clerical       0.865517
#  Armed-Forces       0.888889
#  Craft-repair       0.773359
#  Exec-managerial    0.515986
#  Farming-fishing    0.884306
#  Handlers-cleaners  0.937226
#  Machine-op-inspct  0.875125
#  Other-service      0.958422
#  Priv-house-serv    0.993289
#  Prof-specialty     0.550966
#  Protective-serv    0.674884
#  Sales              0.730685
#  Tech-support       0.695043
#  Transport-moving   0.799624

# %%
df[['workclass','salary']].groupby(['workclass']).mean()
# Out:
#                      salary
# workclass
#  Federal-gov       0.613542
#  Local-gov         0.705208
#  Private           0.781327
#  Self-emp-inc      0.442652
#  Self-emp-not-inc  0.715073
#  State-gov         0.728043
#  Without-pay       1.000000

# %%
def f(x):
    if x['workclass'] == ' Federal-gov' or x['workclass']== ' Local-gov' or x['workclass']==' State-gov': return 'govt'
    elif x['workclass'] == ' Private':return 'private'
    elif x['workclass'] == ' Self-emp-inc' or x['workclass'] == ' Self-emp-not-inc': return 'self_employed'
    else: return 'without_pay'
    
df['employment_type']=df.apply(f, axis=1)

df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  marital-status  \
# 0   39          State-gov   77516   Bachelors             13               1
# 1   50   Self-emp-not-inc   83311   Bachelors             13               0
# 2   38            Private  215646     HS-grad              9               1
# 3   53            Private  234721        11th              7               0
# 4   28            Private  338409   Bachelors             13               0
# 5   37            Private  284582     Masters             14               0
# 6   49            Private  160187         9th              5               1
# 7   52   Self-emp-not-inc  209642     HS-grad              9               0
# 8   31            Private   45781     Masters             14               1
# 9   42            Private  159449   Bachelors             13               0
#
#            occupation  relationship  sex  capital-gain  capital-loss  \
# 0        Adm-clerical             3    1          2174             0
# 1     Exec-managerial             2    1             0             0
# 2   Handlers-cleaners             3    1             0             0
# 3   Handlers-cleaners             2    1             0             0
# 4      Prof-specialty             1    0             0             0
# 5     Exec-managerial             1    0             0             0
# 6       Other-service             3    0             0             0
# 7     Exec-managerial             2    1             0             0
# 8      Prof-specialty             3    0         14084             0
# 9     Exec-managerial             2    1          5178             0
#
#    hours-per-week  country  salary employment_type
# 0              40        1       1            govt
# 1              13        1       1   self_employed
# 2              40        1       1         private
# 3              40        1       1         private
# 4              40        0       1         private
# 5              40        1       1         private
# 6              16        0       1         private
# 7              45        1       0   self_employed
# 8              50        1       0         private
# 9              40        1       0         private

# %%
df[['employment_type','salary']].groupby(['employment_type']).mean()
# Out:
#                    salary
# employment_type
# govt             0.691795
# private          0.781327
# self_employed    0.631939
# without_pay      1.000000

# %%
employment_map = {'govt':0,'private':1,'self_employed':2,'without_pay':3}

df['employment_type'] = df['employment_type'].map(employment_map)
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  marital-status  \
# 0   39          State-gov   77516   Bachelors             13               1
# 1   50   Self-emp-not-inc   83311   Bachelors             13               0
# 2   38            Private  215646     HS-grad              9               1
# 3   53            Private  234721        11th              7               0
# 4   28            Private  338409   Bachelors             13               0
# 5   37            Private  284582     Masters             14               0
# 6   49            Private  160187         9th              5               1
# 7   52   Self-emp-not-inc  209642     HS-grad              9               0
# 8   31            Private   45781     Masters             14               1
# 9   42            Private  159449   Bachelors             13               0
#
#            occupation  relationship  sex  capital-gain  capital-loss  \
# 0        Adm-clerical             3    1          2174             0
# 1     Exec-managerial             2    1             0             0
# 2   Handlers-cleaners             3    1             0             0
# 3   Handlers-cleaners             2    1             0             0
# 4      Prof-specialty             1    0             0             0
# 5     Exec-managerial             1    0             0             0
# 6       Other-service             3    0             0             0
# 7     Exec-managerial             2    1             0             0
# 8      Prof-specialty             3    0         14084             0
# 9     Exec-managerial             2    1          5178             0
#
#    hours-per-week  country  salary  employment_type
# 0              40        1       1                0
# 1              13        1       1                2
# 2              40        1       1                1
# 3              40        1       1                1
# 4              40        0       1                1
# 5              40        1       1                1
# 6              16        0       1                1
# 7              45        1       0                2
# 8              50        1       0                1
# 9              40        1       0                1

# %%
df[['education','salary']].groupby(['education']).mean()
# Out:
#                  salary
# education
#  10th          0.927798
#  11th          0.943182
#  12th          0.921120
#  1st-4th       0.961538
#  5th-6th       0.953795
#  7th-8th       0.933682
#  9th           0.943844
#  Assoc-acdm    0.746078
#  Assoc-voc     0.736563
#  Bachelors     0.580085
#  Doctorate     0.258794
#  HS-grad       0.836577
#  Masters       0.438209
#  Preschool     1.000000
#  Prof-school   0.256272
#  Some-college  0.800443

# %%
df.drop(labels=['workclass','education','occupation'],axis=1,inplace=True)
df.head(10)
# Out:
#    age  fnlwgt  education-num  marital-status  relationship  sex  \
# 0   39   77516             13               1             3    1
# 1   50   83311             13               0             2    1
# 2   38  215646              9               1             3    1
# 3   53  234721              7               0             2    1
# 4   28  338409             13               0             1    0
# 5   37  284582             14               0             1    0
# 6   49  160187              5               1             3    0
# 7   52  209642              9               0             2    1
# 8   31   45781             14               1             3    0
# 9   42  159449             13               0             2    1
#
#    capital-gain  capital-loss  hours-per-week  country  salary  \
# 0          2174             0              40        1       1
# 1             0             0              13        1       1
# 2             0             0              40        1       1
# 3             0             0              40        1       1
# 4             0             0              40        0       1
# 5             0             0              40        1       1
# 6             0             0              16        0       1
# 7             0             0              45        1       0
# 8         14084             0              50        1       0
# 9          5178             0              40        1       0
#
#    employment_type
# 0                0
# 1                2
# 2                1
# 3                1
# 4                1
# 5                1
# 6                1
# 7                2
# 8                1
# 9                1

# %%
x = df['education-num']
plt.hist(x,bins=None,density=True,normed=None,histtype='bar')
plt.show()

# %%
x=df['capital-gain']
plt.hist(x,bins=None,normed=None)
plt.show()

# %%
df.loc[(df['capital-gain'] > 0),'capital-gain'] = 1
df.loc[(df['capital-gain'] == 0 ,'capital-gain')]= 0

# %%
df.head(25)
# Out:
#     age  fnlwgt  education-num  marital-status  relationship  sex  \
# 0    39   77516             13               1             3    1
# 1    50   83311             13               0             2    1
# 2    38  215646              9               1             3    1
# 3    53  234721              7               0             2    1
# 4    28  338409             13               0             1    0
# 5    37  284582             14               0             1    0
# 6    49  160187              5               1             3    0
# 7    52  209642              9               0             2    1
# 8    31   45781             14               1             3    0
# 9    42  159449             13               0             2    1
# 10   37  280464             10               0             2    1
# 11   30  141297             13               0             2    1
# 12   23  122272             13               1             4    0
# 13   32  205019             12               1             3    1
# 14   40  121772             11               0             2    1
# 15   34  245487              4               0             2    1
# 16   25  176756              9               1             4    1
# 17   32  186824              9               1             0    1
# 18   38   28887              7               0             2    1
# 19   43  292175             14               1             0    0
# 20   40  193524             16               0             2    1
# 21   54  302146              9               1             0    0
# 22   35   76845              5               0             2    1
# 23   43  117037              7               0             2    1
# 24   59  109015              9               1             0    0
#
#     capital-gain  capital-loss  hours-per-week  country  salary  \
# 0              1             0              40        1       1
# 1              0             0              13        1       1
# 2              0             0              40        1       1
# 3              0             0              40        1       1
# 4              0             0              40        0       1
# 5              0             0              40        1       1
# 6              0             0              16        0       1
# 7              0             0              45        1       0
# 8              1             0              50        1       0
# 9              1             0              40        1       0
# 10             0             0              80        1       0
# 11             0             0              40        0       0
# 12             0             0              30        1       1
# 13             0             0              50        1       1
# 14             0             0              40        0       0
# 15             0             0              45        0       1
# 16             0             0              35        1       1
# 17             0             0              40        1       1
# 18             0             0              50        1       1
# 19             0             0              45        1       0
# 20             0             0              60        1       0
# 21             0             0              20        1       1
# 22             0             0              40        1       1
# 23             0          2042              40        1       1
# 24             0             0              40        1       1
#
#     employment_type
# 0                 0
# 1                 2
# 2                 1
# 3                 1
# 4                 1
# 5                 1
# 6                 1
# 7                 2
# 8                 1
# 9                 1
# 10                1
# 11                0
# 12                1
# 13                1
# 14                1
# 15                1
# 16                2
# 17                1
# 18                1
# 19                2
# 20                1
# 21                1
# 22                0
# 23                1
# 24                1

# %%
x=df['capital-loss']
plt.hist(x,bins=None)
plt.show()

# %%
df.loc[(df['capital-loss'] > 0),'capital-loss'] = 1
df.loc[(df['capital-loss'] == 0 ,'capital-loss')]= 0

df.head(10)
# Out:
#    age  fnlwgt  education-num  marital-status  relationship  sex  \
# 0   39   77516             13               1             3    1
# 1   50   83311             13               0             2    1
# 2   38  215646              9               1             3    1
# 3   53  234721              7               0             2    1
# 4   28  338409             13               0             1    0
# 5   37  284582             14               0             1    0
# 6   49  160187              5               1             3    0
# 7   52  209642              9               0             2    1
# 8   31   45781             14               1             3    0
# 9   42  159449             13               0             2    1
#
#    capital-gain  capital-loss  hours-per-week  country  salary  \
# 0             1             0              40        1       1
# 1             0             0              13        1       1
# 2             0             0              40        1       1
# 3             0             0              40        1       1
# 4             0             0              40        0       1
# 5             0             0              40        1       1
# 6             0             0              16        0       1
# 7             0             0              45        1       0
# 8             1             0              50        1       0
# 9             1             0              40        1       0
#
#    employment_type
# 0                0
# 1                2
# 2                1
# 3                1
# 4                1
# 5                1
# 6                1
# 7                2
# 8                1
# 9                1

# %%
df['age'].count()
# Out:
# 30718

# %%
import seaborn as sns

def hide_current_axis(*args, **kwds):
    plt.gca().set_visible(False)

g = sns.PairGrid(df, hue="salary")

g.map_diag(sns.kdeplot)
g.map_upper(sns.regplot, truncate=True, scatter_kws=dict(alpha=0.2))
g.map_lower(hide_current_axis)

plt.show()
# Out:
# /anaconda3/envs/py36/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /anaconda3/envs/py36/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /anaconda3/envs/py36/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /anaconda3/envs/py36/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %% [markdown]
# ## Applying model for learning

# %% [markdown]
# ### Divide data in training, validation and test dataset

# %% [markdown]
# #### 50% training data, 20% validation data, 30% test data

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['salary'],axis=1)
y = df['salary']

split_size=0.3

#Creation of Train and Test dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=split_size,random_state=22)

#Creation of Train and validation dataset
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.2,random_state=5)

# %%
print ("Train dataset: {0}{1}".format(X_train.shape, y_train.shape))
print ("Validation dataset: {0}{1}".format(X_val.shape, y_val.shape))
print ("Test dataset: {0}{1}".format(X_test.shape, y_test.shape))
# Out:
# Train dataset: (17201, 11)(17201,)
# Validation dataset: (4301, 11)(4301,)
# Test dataset: (9216, 11)(9216,)

# %% [markdown]
# ### Let's select few algorithm used for classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
models = []
names = ['LR','Random Forest','Neural Network','GaussianNB','DecisionTreeClassifier','SVM',]

models.append((LogisticRegression()))
models.append((RandomForestClassifier(n_estimators=100)))
models.append((MLPClassifier()))
models.append((GaussianNB()))
models.append((DecisionTreeClassifier()))
models.append((SVC()))

# %%
print(models)
# Out:
# [LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False), RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False), MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False), GaussianNB(priors=None, var_smoothing=1e-09), DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)]

# %%
from sklearn import model_selection
from sklearn.metrics import accuracy_score

# %%
kfold = model_selection.KFold(n_splits=5,random_state=7)

for i in range(0,len(models)):    
    cv_result = model_selection.cross_val_score(models[i],X_train,y_train,cv=kfold,scoring='accuracy')
    score=models[i].fit(X_train,y_train)
    prediction = models[i].predict(X_val)
    acc_score = accuracy_score(y_val,prediction)     
    print('-'*40)
    print('{0}: {1}'.format(names[i],acc_score))
# Out:
# ----------------------------------------
# LR: 0.7444780283654964
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ----------------------------------------
# Random Forest: 0.8216693792141363
# ----------------------------------------
# Neural Network: 0.7142524994187398
# ----------------------------------------
# GaussianNB: 0.7674959311787957
# ----------------------------------------
# DecisionTreeClassifier: 0.7767960939316438
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /anaconda3/envs/py36/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ----------------------------------------
# SVM: 0.7465705649848873

# %% [markdown]
# ##### Let's proceed further with Random Forest algorithm as it showed good accuracy

# %% [markdown]
# #### Let's predict our test data and see prediction results

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
randomForest = RandomForestClassifier(n_estimators=100)
randomForest.fit(X_train,y_train)
prediction = randomForest.predict(X_test)

# %%
print ('-'*40)
print ('Accuracy score:')
print (accuracy_score(y_test,prediction))
print ('-'*40)
print ('Confusion Matrix:')
print (confusion_matrix(y_test,prediction))
print ('-'*40)
print ('Classification Matrix:')
print (classification_report(y_test,prediction))
# Out:
# ----------------------------------------
# Accuracy score:
# 0.8212890625
# ----------------------------------------
# Confusion Matrix:
# [[1312  955]
#  [ 692 6257]]
# ----------------------------------------
# Classification Matrix:
#               precision    recall  f1-score   support
#
#            0       0.65      0.58      0.61      2267
#            1       0.87      0.90      0.88      6949
#
#    micro avg       0.82      0.82      0.82      9216
#    macro avg       0.76      0.74      0.75      9216
# weighted avg       0.82      0.82      0.82      9216
